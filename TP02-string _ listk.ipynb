# %% [markdown]
# ## Strings

# %%
'Monday'

print('single word')
# Out:
# single word

# %%
print("two word")
'Good morning'
# Out:
# two word
# 'Good morning'

# %%
print("complete sentence:")
"She eats apple"
# Out:
# complete sentence:
# 'She eats apple'

# %%
print('Be careful with quotes!')
" I'm using single quotes, but this will create an error"
# Out:
# Be careful with quotes!
# " I'm using single quotes, but this will create an error"

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %%
# Note that we can't output multiple strings this way
'Hello World 1'
'Hello World 2'
# Out:
# 'Hello World 2'

# %%
print('Hello World 1')
print('Hello World 2')
print('Use \n to print a new line')
print('\n')
# Out:
# Hello World 1
# Hello World 2
# Use
#  to print a new line

# %%
len('good morning')
# Out:
# 12

# %%
# Assign s as a string
g = 'Good morning'

# %%
print(g)
# Out:
# Good morning

# %%
print(g[0])
# Out:
# G

# %%
print(g[6])
# Out:
# o

# %%
# Grab everything past the first term all the way to the length of s which is len(s)
g[4:]
# Out:
# ' morning'

# %%
# Grab everything UP TO the 3rd index
g[:4]
# Out:
# 'Good'

# %%
#Everything
g[:]
# Out:
# 'Good morning'

# %%
# Last letter (one index behind 0 so it loops back around)
g[-1]
# Out:
# 'g'

# %%
# Grab everything but the last letter
g[:-1]
# Out:
# 'Good mornin'

# %%
# Grab everything, but go in steps size of 1
g[::1]
# Out:
# 'Good morning'

# %%
# Grab everything, but go in step sizes of 2
g[::2]
# Out:
# 'Go onn'

# %%
# We can use this to print a string backwards
g[::-1]
# Out:
# 'gninrom dooG'

# %% [markdown]
# ## String Properties

# %%
g
# Out:
# 'Good morning'

# %%
# Let's try to change the first letter to 'd'
g[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15700\2906778356.py in <module>
#       1 # Let's try to change the first letter to 'd'
# ----> 2 g[0] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %%
# Concatenate strings!
g + ' concatenate me!'
# Out:
# 'Good morning concatenate me!'

# %%
# We can reassign g completely though!
g = g + ' concatenate me!'

# %%
g
# Out:
# 'Good morning concatenate me!'

# %%
letter = 'b'

# %%
letter*10
# Out:
# 'bbbbbbbbbb'

# %% [markdown]
# ## Basic Built-in String methods

# %%
# Upper Case a string
g.upper()
# Out:
# 'GOOD MORNING CONCATENATE ME!'

# %%
# Lower case
g.lower()
# Out:
# 'good morning concatenate me!'

# %%
# Split a string by blank space (this is the default)
g.split()
# Out:
# ['Good', 'morning', 'concatenate', 'me!']

# %%
# Split by a specific element (doesn't include the element that was split on)
g.split('m')
# Out:
# ['Good ', 'orning concatenate ', 'e!']

# %%
'Insert another string with curly brackets: {}'.format('The inserted string')
# Out:
# 'Insert another string with curly brackets: The inserted string'

# %% [markdown]
# EX01
# Ecrire un programme en Python permettant de supprimer les espaces multiples dans une chaine g.

# %%
g = input("Entrez une chaine avec des espaces multiples : ")
l = g.split()
chaines_sans_espaces = " ".join(l)

print(chaines_sans_espaces)
# Out:
# bonjour alban comment ça va

# %%
g.upper()
g.lower()
g.split('m')

# %%
g = "Exemple     de texte avec des    espaces     multiple"
print(g)
# Transformer le texte en une liste 
L = g.split()
print(L)
# initialiser le texte sans espace à un texte vide
texteSansEspace = ""

# Reconstruire le texte en parcourant les éléments de la liste 
for x in L:
    texteSansEspace = texteSansEspace + x + " "
print(texteSansEspace)
# Out:
# Exemple     de texte avec des    espaces     multiple
# ['Exemple', 'de', 'texte', 'avec', 'des', 'espaces', 'multiple']
# Exemple de texte avec des espaces multiple

# %% [markdown]
# Ex02
#
# Ecrire un programme Python qui permet de chercher le mot le plus long sur une chaine g

# %%
def motLong(g):
    g = g.split()
    mL = ""
    for element in g:
        if len(element)>len(mL):
            mL = element
    return mL

# %%
def motMax(g):
    L = g.split()
    mot = ""
    for x in L:
        if(len(x)>len(mot)):
            mot = x
    return mot
# Exemple
g = "Python est un langage de programmation orienté objet"
print("Le mot le plus long dans la chaine g est : ", motMax(g))

# %% [markdown]
# Ex 03:
# Ecrire un programme Python qui permet de compter le nombres de mots sur une chaîne g. On suppose que le texte est bien formé ( un espace après chaque ponctuation et aucun espace avant la ponctuation)

# %%
def nbMots(g):
    g = g.split()
    cpt = 0
    for element in g:
        cpt += 1
    return cpt

# %%
def nbMots(g):
    return len(g.split())

# %%
g = "Python est un langage de programmation. Python est orienté objet"

# Transformation de la chaine s en une liste
L = g.split()
print('L: ',L)
# Récupération du nombre d'élément de la liste L
nombreMots = len(L)
print("Le nombre de mot de la chaine g est : ", nombreMots)

# %% [markdown]
# EX04:Ecrire un programme Python qui permet d'échanger le premier et le dernier mot. Exemple si g ="Pyhon est un langage de programmation", le programme renvoie la chaine g1 = "programmation  est un langage de Pyhon". On suppose que le texte est bien formé ( un espace après chaque ponctuation et aucun espace avant la ponctuation).

# %%
def echangePremierDernier(g):
    g = g.split()
    if len(g) < 2:
        return " ".join(g)
    g[0], g[-1] = g[-1], g[0]
    g = " ".join(g)
    return g

# %%
g = "Python est un langage de programmation"

# Transformation de la chaine s en une liste L
L = g.split()

# Récupération du nombre d'élément de la liste L
n = len(L)

# récupération du premier et dernier élément
premier = L[0]
dernier = L[n-1]

# On supprime le premier et le dernier élément de la liste L
L.pop(n-1)
L.pop(0)

# On reconvertit la liste L en une chaine
g1 = " ".join(L)

# %%
dernier+' '+g1+' '+premier
# Out:
# 'programmation est un langage de Python'

# %% [markdown]
# ## Lists

# %%
# Assign a list to an variable named my_list
my_list = [1,2,6]

# %%
my_list
# Out:
# [1, 2, 6]

# %%
my_list = ['A string',23,10.532,'k']

# %%
my_list
# Out:
# ['A string', 23, 10.532, 'k']

# %%
len(my_list)
# Out:
# 4

# %%
my_list = ['one','five','three',6,45]

# %%
# Grab element at index 2
my_list[2]
# Out:
# 'three'

# %%
# Grab index 2 and everything past it
my_list[2:]
# Out:
# ['three', 6, 45]

# %%
# Grab everything UP TO index 3
my_list[:3]
# Out:
# ['one', 'five', 'three']

# %%
my_list + ['new item']
# Out:
# ['one', 'five', 'three', 6, 45, 'new item']

# %%
my_list
# Out:
# ['one', 'five', 'three', 6, 45]

# %%
# Reassign
my_list = my_list + ['add new item permanently']

# %%
my_list
# Out:
# ['one', 'five', 'three', 6, 45, 'add new item permanently']

# %%
# Make the list double
my_list * 2
# Out:
# ['one',
#  'five',
#  'three',
#  6,
#  45,
#  'add new item permanently',
#  'one',
#  'five',
#  'three',
#  6,
#  45,
#  'add new item permanently']

# %%
# Again doubling not permanent
my_list
# Out:
# ['one', 'five', 'three', 6, 45, 'add new item permanently']

# %% [markdown]
# ## Basic List Methods

# %%
# Create a new list
list1 = [1,7,8]

# %%
# Append
list1.append('append me!')

# %%
# Show
list1
# Out:
# [1, 7, 8, 'append me!']

# %%
# Pop off the 0 indexed item
list1.pop(0)
# Out:
# 1

# %%
# Show
list1
# Out:
# [7, 8, 'append me!']

# %%
# Assign the popped element, remember default popped index is -1
popped_item = list1.pop()

# %%
popped_item
# Out:
# 'append me!'

# %%
# Show remaining list
list1
# Out:
# [7, 8]

# %%
new_list = ['a','e','x','b','c']

# %%
#Show
new_list
# Out:
# ['a', 'e', 'x', 'b', 'c']

# %%
# Use reverse to reverse order (this is permanent!)
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
# Use sort to sort the list (in this case alphabetical order, but for numbers it will go ascending)
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# ## Nesting Lists

# %%
# Let's make three lists
lst_1=[1,2,9]
lst_2=[4,8,6]
lst_3=[7,1,9]

# Make a list of lists to form a matrix
matrix = [lst_1,lst_2,lst_3]

# %%
# Show
matrix
# Out:
# [[1, 2, 9], [4, 8, 6], [7, 1, 9]]

# %%
type(matrix)
# Out:
# list

# %%
# Grab first item in matrix object
matrix[0]
# Out:
# [1, 2, 9]

# %%
# Grab first item of the first item in the matrix object
matrix[0][1]
# Out:
# 2

# %% [markdown]
# Ex01
# Créez une fonction Python, appelée nombreDivisibles, qui s'applique à une liste de nombres et un entier n, et qui renvoie le nombre d’éléments de la liste qui sont divisible par n.

# %%
def nombreDivisibles(l,n):
    i = 0
    for k in l:
        if( k%n == 0):
            i = i + 1
    return i
l = [12, 4, 7, 9,11]
n = 3
print("Le nombre d'élément de l qui sont divisible par ",n, " est : ",nombreDivisibles(l,n))

# %% [markdown]
# Ex02
#
# Créer une fonction en Python nombreOccurences() qui s’applique à une liste L et un élément x comme paramètres et qui retourne le nombre de fois où l’élément x apparait dans la liste L sans utiliser la fonction count().

# %%
def nombreOccurences(L , x):
    occ = 0
    for element in L:
        if element == x:
            occ += 1
    return occ
        
L = [3 , 11 , 3 ,9  , 23 , 3,  7 , 11, 3]
print("Le nombr d'occurrences de 3 dans l est : " , nombreOccurences(L,3))
# Out:
# Le nombr d'occurrences de 3 dans l est :  4

# %% [markdown]
# Ex03
#
# Ecrire un programme en Python qui permet de lister les chaines qui composent la liste l = ["laptop", "iphone", "tablet"] tout en indiquant la longueur de chaque chaine.

# %%
l = ["laptop", "iphone", "tablet", "printer", "Ipad"]
# parcourir les éléments de la liste  l
for x in l:
    print(x, " is in list l, its length is: ", len(x))
# Out:
# laptop  is in list l, its length is:  6
# iphone  is in list l, its length is:  6
# tablet  is in list l, its length is:  6
# printer  is in list l, its length is:  7
# Ipad  is in list l, its length is:  4

# %% [markdown]
# ex04
# Écrire un programme en Python sous forme de fonction qui calcul la somme des éléments d'une liste de nombres. Et un autre qui permet de multiplier tous les éléments d'une liste de nombres.

# %%
# Fonction qui calcul le produit des éléments d'une liste
def mult(l):
    m = 1 
    # Création du produit en parcourant les éléments de la liste
    for x in l:
        m = m*x
    return m
print(mult([2,5,3]))

# Fonction qui calcul la somme des éléments d'une liste
def sum(l):
    s = 0 
    # Création de la somme en parcourant les éléments de la liste
    for x in l:
        s = s + x
    return s
print(sum([2,5,3]))
# Out:
# 30
# 10

# %% [markdown]
# Ex05
# Écrire un programme Python qui teste si une liste est vide ou non. Même question pour une chaine de caractères.

# %%
# Tester si une liste L est vide
# définir une liste L
L = list()

# essayer si la liste L est vide
if L == []:
    print ("La liste L est vide")
else:
    print ("La liste L n'est pas vide")


#Tester si une chaîne est vide


# définir une chaîne s
s = ""

# Tester si une chaîne s est vide
if s == "":
    print ("La chaîne s est vide")
else:
    print ("La liste n'est pas vide")
# Out:
# La liste L est vide
# La chaîne s est vide

# %%
# définir une liste L
L = list()

# 1) - Tester si la liste L est vide en utilisant la fonction len ()
if len(L) == 0:
    print ("La liste L est vide")
else:
    print ("La liste L n'est pas vide")


#2) - Tester si une chaîne s est vide
# définir une chaîne s
s = ""

#Tester si la chaîne s est vide en utilisant la fonction len ()
if len (s) == 0:
    print ("La chaîne s est vide")
else:
    print ("La liste L n'est pas vide")
